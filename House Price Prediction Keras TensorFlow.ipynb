# %% [markdown]
# # Data Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.figure(figsize=(10,8))

# %%
df = pd.read_csv("C:/Users/diwak/Downloads/TensorFlow_FILES/DATA/kc_house_data.csv")

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180  \
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement
# 0      5650     1.0           0     0  ...      7        1180              0  \
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15
# ...

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
plt.figure(figsize=(15,8))
sns.displot(df['price'],kde=True,bins=50)

# %%
df1 = df.drop(['date'],axis=1)
df1.corr()['price']
# Out:
# id              -0.016772
# price            1.000000
# bedrooms         0.308787
# bathrooms        0.525906
# sqft_living      0.701917
# sqft_lot         0.089876
# floors           0.256804
# waterfront       0.266398
# view             0.397370
# condition        0.036056
# grade            0.667951
# sqft_above       0.605368
# sqft_basement    0.323799
# yr_built         0.053953
# yr_renovated     0.126424
# zipcode         -0.053402
# lat              0.306692
# long             0.022036
# sqft_living15    0.585241
# sqft_lot15       0.082845
# Name: price, dtype: float64

# %%
sns.scatterplot(x='price',y='sqft_living',data=df)
# Out:
# <Axes: xlabel='price', ylabel='sqft_living'>

# %%
plt.figure(figsize=(12,8))
sns.distplot(df['bedrooms'],kde=False,bins=50)
# Out:
# C:\Users\diwak\AppData\Local\Temp\ipykernel_7684\310094766.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bedrooms'],kde=False,bins=50)
# <Axes: xlabel='bedrooms'>

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='long',y='lat',data=df,hue='price',palette='viridis')
# Out:
# <Axes: xlabel='long', ylabel='lat'>

# %%
df.sort_values('price',ascending=False).head(20)
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living
# 7245   6762700020  10/13/2014  7700000.0         6       8.00        12050  \
# 3910   9808700762   6/11/2014  7060000.0         5       4.50        10040
# 9245   9208900037   9/19/2014  6890000.0         6       7.75         9890
# 4407   2470100110    8/4/2014  5570000.0         5       5.75         9200
# 1446   8907500070   4/13/2015  5350000.0         5       5.00         8000
# 1313   7558700030   4/13/2015  5300000.0         6       6.00         7390
# 1162   1247600105  10/20/2014  5110000.0         5       5.25         8010
# 8085   1924059029   6/17/2014  4670000.0         5       6.75         9640
# 2624   7738500731   8/15/2014  4500000.0         5       5.50         6640
# 8629   3835500195   6/18/2014  4490000.0         4       3.00         6430
# 12358  6065300370    5/6/2015  4210000.0         5       6.00         7440
# ...

# %%
len(df)*0.01 #10% data
# Out:
# 215.97

# %%
non_top_1_percent = df.sort_values('price',ascending=False).iloc[215:]

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='long',y='lat',data=non_top_1_percent,hue='price',palette='RdYlGn',edgecolor=None,alpha=0.2)
# Out:
# <Axes: xlabel='long', ylabel='lat'>

# %%
# Comparing how the prices affect if property is near to water
sns.boxplot(x='waterfront',y='price',data=df)
# Out:
# <Axes: xlabel='waterfront', ylabel='price'>

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180  \
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement
# 0      5650     1.0           0     0  ...      7        1180              0  \
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     21597 non-null  int64
#  9   view           21597 non-null  int64
#  10  condition      21597 non-null  int64
#  11  grade          21597 non-null  int64
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  int64
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   21597 non-null  int64
#  16  zipcode        21597 non-null  int64
# ...

# %%
df = df.drop('id',axis=1)

# %%
df.head()
# Out:
#          date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors
# 0  10/13/2014  221900.0         3       1.00         1180      5650     1.0  \
# 1   12/9/2014  538000.0         3       2.25         2570      7242     2.0
# 2   2/25/2015  180000.0         2       1.00          770     10000     1.0
# 3   12/9/2014  604000.0         4       3.00         1960      5000     1.0
# 4   2/18/2015  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built
# 0           0     0          3      7        1180              0      1955  \
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
# 3           0     0          5      7        1050            910      1965
# 4           0     0          3      8        1680              0      1987
#
# ...

# %% [markdown]
# # EDA

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df['date']
# Out:
# 0       2014-10-13
# 1       2014-12-09
# 2       2015-02-25
# 3       2014-12-09
# 4       2015-02-18
#            ...
# 21592   2014-05-21
# 21593   2015-02-23
# 21594   2014-06-23
# 21595   2015-01-16
# 21596   2014-10-15
# Name: date, Length: 21597, dtype: datetime64[ns]

# %%
df['year'] = df['date'].apply(lambda date:date.year)
df['month'] = df['date'].apply(lambda date:date.month)

# %%
df.head()
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors
# 0 2014-10-13  221900.0         3       1.00         1180      5650     1.0  \
# 1 2014-12-09  538000.0         3       2.25         2570      7242     2.0
# 2 2015-02-25  180000.0         2       1.00          770     10000     1.0
# 3 2014-12-09  604000.0         4       3.00         1960      5000     1.0
# 4 2015-02-18  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_basement  yr_built  yr_renovated
# 0           0     0          3  ...              0      1955             0  \
# 1           0     0          3  ...            400      1951          1991
# 2           0     0          3  ...              0      1933             0
# 3           0     0          5  ...            910      1965             0
# 4           0     0          3  ...              0      1987             0
#
# ...

# %%
df['year'].unique()
# Out:
# array([2014, 2015], dtype=int64)

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x=df['month'],y=df['price'],data=df)
# Out:
# <Axes: xlabel='month', ylabel='price'>

# %%
df = df.drop(['date'],axis=1)

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront
# 0  221900.0         3       1.00         1180      5650     1.0           0  \
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  ...  sqft_basement  yr_built  yr_renovated
# 0     0          3      7  ...              0      1955             0  \
# 1     0          3      7  ...            400      1951          1991
# 2     0          3      6  ...              0      1933             0
# 3     0          5      7  ...            910      1965             0
# 4     0          3      8  ...              0      1987             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15  year  month
# ...

# %% [markdown]
# ## Scaling and training data

# %%
X=df.drop('price',axis=1)
y=df['price']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
X_train.shape
# Out:
# (15117, 20)

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler

# %%
mmscaler = MinMaxScaler()

# %%
mmscaler.fit(X_train)
# Out:
# MinMaxScaler()

# %%
X_train=mmscaler.transform(X_train)
X_test=mmscaler.transform(X_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation,Dense
from tensorflow.keras.optimizers import Adam

# %%
model = Sequential()

model.add(Dense(units=19,activation='relu'))
model.add(Dense(units=19,activation='relu'))
model.add(Dense(units=19,activation='relu'))
model.add(Dense(units=19,activation='relu'))

model.add(Dense(units=1))

model.compile(optimizer='adam',loss='mse')

# %% [markdown]
# ## Training Model

# %%
model.fit(x=X_train,y=y_train.values,validation_data=(X_test,y_test.values),batch_size=128,epochs=400)
# Out:
# Epoch 1/400
# 119/119 [==============================] - 1s 4ms/step - loss: 430239645696.0000 - val_loss: 418913878016.0000
# Epoch 2/400
# 119/119 [==============================] - 0s 3ms/step - loss: 429203161088.0000 - val_loss: 415350423552.0000
# Epoch 3/400
# 119/119 [==============================] - 0s 3ms/step - loss: 414736809984.0000 - val_loss: 382037557248.0000
# Epoch 4/400
# 119/119 [==============================] - 0s 3ms/step - loss: 342390308864.0000 - val_loss: 263923974144.0000
# Epoch 5/400
# 119/119 [==============================] - 0s 3ms/step - loss: 192822018048.0000 - val_loss: 120644993024.0000
# Epoch 6/400
# 119/119 [==============================] - 0s 3ms/step - loss: 107268890624.0000 - val_loss: 97504321536.0000
# Epoch 7/400
# 119/119 [==============================] - 0s 3ms/step - loss: 99747495936.0000 - val_loss: 95926820864.0000
# Epoch 8/400
# ...

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses #adding that validation data in training helps us to track the loss and we get a dataframe for loss in training data and validation data
# Out:
#              loss      val_loss
# 0    4.302396e+11  4.189139e+11
# 1    4.292032e+11  4.153504e+11
# 2    4.147368e+11  3.820376e+11
# 3    3.423903e+11  2.639240e+11
# 4    1.928220e+11  1.206450e+11
# ..            ...           ...
# 395  2.571194e+10  2.575174e+10
# 396  2.565934e+10  2.576586e+10
# 397  2.565886e+10  2.566833e+10
# 398  2.569286e+10  2.579679e+10
# 399  2.563972e+10  2.567662e+10
#
# [400 rows x 2 columns]

# %%
losses.plot() #adding that validation data in training helps us to track the loss and we can visualise through plot
# Out:
# <Axes: >

# %%
#let update the epochs and see how loss varies

# %%
model.fit(x=X_train,y=y_train.values,validation_data=(X_test,y_test.values),batch_size=128,epochs=600)
# Out:
# Epoch 1/600
# 119/119 [==============================] - 0s 3ms/step - loss: 25655066624.0000 - val_loss: 25629163520.0000
# Epoch 2/600
# 119/119 [==============================] - 0s 3ms/step - loss: 25632397312.0000 - val_loss: 25851537408.0000
# Epoch 3/600
# 119/119 [==============================] - 0s 3ms/step - loss: 25692452864.0000 - val_loss: 25664180224.0000
# Epoch 4/600
# 119/119 [==============================] - 0s 3ms/step - loss: 25599557632.0000 - val_loss: 25807212544.0000
# Epoch 5/600
# 119/119 [==============================] - 0s 3ms/step - loss: 25606588416.0000 - val_loss: 25680584704.0000
# Epoch 6/600
# 119/119 [==============================] - 0s 3ms/step - loss: 25574868992.0000 - val_loss: 25697835008.0000
# Epoch 7/600
# 119/119 [==============================] - 0s 3ms/step - loss: 25629847552.0000 - val_loss: 25636896768.0000
# Epoch 8/600
# 119/119 [==============================] - 0s 3ms/step - loss: 25661786112.0000 - val_loss: 25582258176.0000
# ...

# %%
losses2 = pd.DataFrame(model.history.history)

# %% [markdown]
# ### Model starts overfitting

# %%
losses2.plot()
# Out:
# <Axes: >

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,explained_variance_score

# %%
predictions = model.predict(X_test)
# Out:
# 203/203 [==============================] - 0s 1ms/step

# %%
predictions
# Out:
# array([[434757.75],
#        [636363.44],
#        [605926.94],
#        ...,
#        [412621.5 ],
#        [579064.75],
#        [695170.9 ]], dtype=float32)

# %%
mean_squared_error(y_test,predictions)
# Out:
# 24677702147.26891

# %%
np.sqrt(mean_squared_error(y_test,predictions)) #root mse
# Out:
# 157091.38151811165

# %%
mean_absolute_error(y_test,predictions)
# Out:
# 95911.6660337095

# %%
explained_variance_score(y_test,predictions) #ranges between 0 and 1  and 1 being the best and here we have 81% accuracy
# Out:
# 0.814632775949034

# %%
plt.figure(figsize=(12,5))
plt.scatter(y_test,predictions,marker='*',c='r')
plt.plot(y_test,y_test,'g')

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront
# 0  221900.0         3       1.00         1180      5650     1.0           0  \
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  ...  sqft_basement  yr_built  yr_renovated
# 0     0          3      7  ...              0      1955             0  \
# 1     0          3      7  ...            400      1951          1991
# 2     0          3      6  ...              0      1933             0
# 3     0          5      7  ...            910      1965             0
# 4     0          3      8  ...              0      1987             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15  year  month
# ...

# %%
single_house = df.drop('price',axis=1).iloc[0]

# %%
single_house = mmscaler.transform(single_house.values.reshape(-1, 20))
# Out:
# C:\Users\diwak\AppData\Roaming\Python\Python310\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %%
model.predict(single_house)
# Out:
# 1/1 [==============================] - 0s 47ms/step
# array([[251693.27]], dtype=float32)

# %%
df.iloc[0]
# Out:
# price            221900.0000
# bedrooms              3.0000
# bathrooms             1.0000
# sqft_living        1180.0000
# sqft_lot           5650.0000
# floors                1.0000
# waterfront            0.0000
# view                  0.0000
# condition             3.0000
# grade                 7.0000
# sqft_above         1180.0000
# sqft_basement         0.0000
# yr_built           1955.0000
# yr_renovated          0.0000
# zipcode           98178.0000
# lat                  47.5112
# long               -122.2570
# sqft_living15      1340.0000
# sqft_lot15         5650.0000
# year               2014.0000
# month                10.0000
# Name: 0, dtype: float64
