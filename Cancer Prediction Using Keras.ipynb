# %%
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("C:/Users/diwak/Downloads/TensorFlow_FILES/DATA/cancer_classification.csv")
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness
# 0        17.99         10.38          122.80     1001.0          0.11840  \
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry
# 0           0.27760          0.3001              0.14710         0.2419  \
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              569 non-null    float64
#  1   mean texture             569 non-null    float64
#  2   mean perimeter           569 non-null    float64
#  3   mean area                569 non-null    float64
#  4   mean smoothness          569 non-null    float64
#  5   mean compactness         569 non-null    float64
#  6   mean concavity           569 non-null    float64
#  7   mean concave points      569 non-null    float64
#  8   mean symmetry            569 non-null    float64
#  9   mean fractal dimension   569 non-null    float64
#  10  radius error             569 non-null    float64
#  11  texture error            569 non-null    float64
#  12  perimeter error          569 non-null    float64
# ...

# %%
df.describe().transpose()
# Out:
#                          count        mean         std         min
# mean radius              569.0   14.127292    3.524049    6.981000  \
# mean texture             569.0   19.289649    4.301036    9.710000
# mean perimeter           569.0   91.969033   24.298981   43.790000
# mean area                569.0  654.889104  351.914129  143.500000
# mean smoothness          569.0    0.096360    0.014064    0.052630
# mean compactness         569.0    0.104341    0.052813    0.019380
# mean concavity           569.0    0.088799    0.079720    0.000000
# mean concave points      569.0    0.048919    0.038803    0.000000
# mean symmetry            569.0    0.181162    0.027414    0.106000
# mean fractal dimension   569.0    0.062798    0.007060    0.049960
# radius error             569.0    0.405172    0.277313    0.111500
# texture error            569.0    1.216853    0.551648    0.360200
# perimeter error          569.0    2.866059    2.021855    0.757000
# ...

# %%
df.corr()['benign_0__mal_1'][:-1].sort_values().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.countplot(x='benign_0__mal_1',data=df)
# Out:
# <Axes: xlabel='benign_0__mal_1', ylabel='count'>

# %% [markdown]
# # Train Test split

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
X = df.drop('benign_0__mal_1',axis=1)
y = df['benign_0__mal_1']

# %%
 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=101)

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %% [markdown]
# ## Tensorflow

# %%
import tensorflow as tf

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Activation,Dropout
from tensorflow.keras.optimizers import Adam

# %%
model = Sequential()

# %%
model.add(Dense(30,activation='relu'))
model.add(Dense(15,activation='relu'))

# Binary Calssification
model.add(Dense(1,activation='sigmoid'))

#complie
model.compile(loss='binary_crossentropy',optimizer='adam')

# %%
model.fit(X_train,y_train,epochs=600,validation_data=(X_test,y_test))
# Out:
# Epoch 1/600
# 15/15 [==============================] - 2s 31ms/step - loss: 0.6625 - val_loss: 0.6499
# Epoch 2/600
# 15/15 [==============================] - 0s 8ms/step - loss: 0.6235 - val_loss: 0.6139
# Epoch 3/600
# 15/15 [==============================] - 0s 7ms/step - loss: 0.5868 - val_loss: 0.5759
# Epoch 4/600
# 15/15 [==============================] - 0s 8ms/step - loss: 0.5497 - val_loss: 0.5353
# Epoch 5/600
# 15/15 [==============================] - 0s 15ms/step - loss: 0.5085 - val_loss: 0.4906
# Epoch 6/600
# 15/15 [==============================] - 0s 7ms/step - loss: 0.4618 - val_loss: 0.4378
# Epoch 7/600
# 15/15 [==============================] - 0s 8ms/step - loss: 0.4111 - val_loss: 0.3933
# Epoch 8/600
# 15/15 [==============================] - 0s 7ms/step - loss: 0.3681 - val_loss: 0.3507
# Epoch 9/600
# 15/15 [==============================] - 0s 7ms/step - loss: 0.3285 - val_loss: 0.3118
# Epoch 10/600
# ...

# %%
losses = pd.DataFrame(model.history.history)
losses.plot()
# Out:
# <Axes: >

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
earlt_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=25)

# %%
model.add(Dense(30,activation='relu'))
model.add(Dense(15,activation='relu'))

# Binary Calssification
model.add(Dense(1,activation='sigmoid'))

#complie
model.compile(loss='binary_crossentropy',optimizer='adam')

# %%
model.fit(X_train,y_train,epochs=600,validation_data=(X_test,y_test),callbacks=earlt_stop)
# Out:
# Epoch 1/600
# 15/15 [==============================] - 3s 28ms/step - loss: 0.6406 - val_loss: 0.5987
# Epoch 2/600
# 15/15 [==============================] - 0s 7ms/step - loss: 0.5620 - val_loss: 0.5470
# Epoch 3/600
# 15/15 [==============================] - 0s 7ms/step - loss: 0.5132 - val_loss: 0.5062
# Epoch 4/600
# 15/15 [==============================] - 0s 8ms/step - loss: 0.4690 - val_loss: 0.4678
# Epoch 5/600
# 15/15 [==============================] - 0s 8ms/step - loss: 0.4300 - val_loss: 0.4342
# Epoch 6/600
# 15/15 [==============================] - 0s 8ms/step - loss: 0.3952 - val_loss: 0.4128
# Epoch 7/600
# 15/15 [==============================] - 0s 7ms/step - loss: 0.3627 - val_loss: 0.3797
# Epoch 8/600
# 15/15 [==============================] - 0s 7ms/step - loss: 0.3356 - val_loss: 0.3562
# Epoch 9/600
# 15/15 [==============================] - 0s 7ms/step - loss: 0.3079 - val_loss: 0.3428
# Epoch 10/600
# ...

# %%
losss = pd.DataFrame(model.history.history)
losss.plot()
# Out:
# <Axes: >

# %%
model.add(Dense(30,activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(15,activation='relu'))
model.add(Dropout(0.5))

# Binary Calssification
model.add(Dense(1,activation='sigmoid'))

#complie
model.compile(loss='binary_crossentropy',optimizer='adam')

# %%
model.fit(X_train,y_train,epochs=600,validation_data=(X_test,y_test),callbacks=earlt_stop)
# Out:
# Epoch 1/600
# 15/15 [==============================] - 2s 25ms/step - loss: 0.6872 - val_loss: 0.6566
# Epoch 2/600
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6518 - val_loss: 0.6321
# Epoch 3/600
# 15/15 [==============================] - 0s 9ms/step - loss: 0.6308 - val_loss: 0.6086
# Epoch 4/600
# 15/15 [==============================] - 0s 7ms/step - loss: 0.6233 - val_loss: 0.5860
# Epoch 5/600
# 15/15 [==============================] - 0s 8ms/step - loss: 0.5956 - val_loss: 0.5610
# Epoch 6/600
# 15/15 [==============================] - 0s 8ms/step - loss: 0.5739 - val_loss: 0.5336
# Epoch 7/600
# 15/15 [==============================] - 0s 15ms/step - loss: 0.5413 - val_loss: 0.5014
# Epoch 8/600
# 15/15 [==============================] - 0s 9ms/step - loss: 0.5272 - val_loss: 0.4727
# Epoch 9/600
# 15/15 [==============================] - 0s 8ms/step - loss: 0.4852 - val_loss: 0.4412
# Epoch 10/600
# ...

# %%
lossss = pd.DataFrame(model.history.history)
lossss.plot()
# Out:
# <Axes: >

# %%
predictions = model.predict(X_test)
# Out:
# 4/4 [==============================] - 0s 4ms/step

# %%
dff = pd.DataFrame(predictions)
dff
# Out:
#             0
# 0    0.989123
# 1    0.988181
# 2    0.994015
# 3    0.003773
# 4    0.999533
# ..        ...
# 109  0.956651
# 110  0.999901
# 111  0.999743
# 112  0.917910
# 113  0.000951
#
# [114 rows x 1 columns]

# %%
def conv(d):
    for i in range(0,len(dff)):
        if(dff[0][i]>0.5):
            dff[0][i]=1
        else:
            dff[0][i]=0
    return

# %%
conv(dff)

# %%
dff
# Out:
#        0
# 0    1.0
# 1    1.0
# 2    1.0
# 3    0.0
# 4    1.0
# ..   ...
# 109  1.0
# 110  1.0
# 111  1.0
# 112  1.0
# 113  0.0
#
# [114 rows x 1 columns]

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
confusion_matrix(y_test, dff)
# Out:
# array([[41,  1],
#        [ 2, 70]], dtype=int64)

# %%
print(classification_report(y_test, dff))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96        42
#            1       0.99      0.97      0.98        72
#
#     accuracy                           0.97       114
#    macro avg       0.97      0.97      0.97       114
# weighted avg       0.97      0.97      0.97       114
